# %% [markdown]
# #### MLS Cup Conference Finals Data Analysis

# %%
# Package List 

import pandas as pd
import numpy as np 
from statsbombpy import sb
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       3 import pandas as pd
#       4 import numpy as np
# ----> 5 from statsbombpy import sb
#       6 import seaborn as sns
#       7 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'statsbombpy'

# %%
# Loading data 
sb.competitions()
# Out:
# /home/jonathansyun/.local/lib/python3.10/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id   country_name        competition_name  \
# 0                9         27        Germany           1. Bundesliga
# 1             1267        107         Africa  African Cup of Nations
# 2               16          4         Europe        Champions League
# 3               16          1         Europe        Champions League
# 4               16          2         Europe        Champions League
# ..             ...        ...            ...                     ...
# 66              55         43         Europe               UEFA Euro
# 67              35         75         Europe      UEFA Europa League
# 68              53        106         Europe       UEFA Women's Euro
# 69              72        107  International       Women's World Cup
# ...

# %%
sb.matches(competition_id= 9, season_id= 42)
# Out:
# /home/jonathansyun/.local/lib/python3.10/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sb.matches(competition_id= 9, season_id= 42)
#
# File ~/.local/lib/python3.10/site-packages/statsbombpy/sb.py:31, in matches(competition_id, season_id, fmt, creds)
#      29     matches = api_client.matches(competition_id, season_id, creds=creds)
#      30 else:
# ---> 31     matches = public.matches(competition_id, season_id)
#      32 if fmt == "dataframe":
#      33     home_managers = [
#      34         (
#      35             ", ".join(
#    (...)
#      41         for match in matches
#      42     ]
#
# File ~/.local/lib/python3.10/site-packages/statsbombpy/public.py:24, in matches(competition_id, season_id)
# ...
