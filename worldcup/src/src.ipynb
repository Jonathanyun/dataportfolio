# %% [markdown]
# #### World Cup Data Analysis

# %%
# Package List 

import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_json('../data/106.json')

# %%
data.head()
# Out:
#    match_id  match_date      kick_off  \
# 0   3857256  2022-12-02  21:00:00.000
# 1   3869151  2022-12-03  21:00:00.000
# 2   3857257  2022-11-30  17:00:00.000
# 3   3857258  2022-11-24  21:00:00.000
# 4   3857288  2022-11-26  12:00:00.000
#
#                                          competition  \
# 0  {'competition_id': 43, 'country_name': 'Intern...
# 1  {'competition_id': 43, 'country_name': 'Intern...
# 2  {'competition_id': 43, 'country_name': 'Intern...
# 3  {'competition_id': 43, 'country_name': 'Intern...
# 4  {'competition_id': 43, 'country_name': 'Intern...
#
#                                       season  \
# 0  {'season_id': 106, 'season_name': '2022'}
# 1  {'season_id': 106, 'season_name': '2022'}
# 2  {'season_id': 106, 'season_name': '2022'}
# 3  {'season_id': 106, 'season_name': '2022'}
# 4  {'season_id': 106, 'season_name': '2022'}
#
#                                            home_team  \
# 0  {'home_team_id': 786, 'home_team_name': 'Serbi...
# ...

# %%
column_names = ['competition', 'season', 'home_team', 'away_team', 'metadata', 'competition_stage', 'stadium', 'referee']

# %%
for i in column_names:
    pd.concat([data.drop([i], axis = 1), data[i].apply(pd.Series)], axis = 1)

# %%
data.head()
# Out:
#    match_id  match_date      kick_off  \
# 0   3857256  2022-12-02  21:00:00.000
# 1   3869151  2022-12-03  21:00:00.000
# 2   3857257  2022-11-30  17:00:00.000
# 3   3857258  2022-11-24  21:00:00.000
# 4   3857288  2022-11-26  12:00:00.000
#
#                                          competition  \
# 0  {'competition_id': 43, 'country_name': 'Intern...
# 1  {'competition_id': 43, 'country_name': 'Intern...
# 2  {'competition_id': 43, 'country_name': 'Intern...
# 3  {'competition_id': 43, 'country_name': 'Intern...
# 4  {'competition_id': 43, 'country_name': 'Intern...
#
#                                       season  \
# 0  {'season_id': 106, 'season_name': '2022'}
# 1  {'season_id': 106, 'season_name': '2022'}
# 2  {'season_id': 106, 'season_name': '2022'}
# 3  {'season_id': 106, 'season_name': '2022'}
# 4  {'season_id': 106, 'season_name': '2022'}
#
#                                            home_team  \
# 0  {'home_team_id': 786, 'home_team_name': 'Serbi...
# ...
